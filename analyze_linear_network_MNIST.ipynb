# %%
# Parameters
param1=1

# %%
import importlib
import run_sim
import data_modules
import utils
import utils_plot

importlib.reload(run_sim)
importlib.reload(data_modules)
importlib.reload(utils)
importlib.reload(utils_plot)
# Out:
# <module 'utils_plot' from '/home/avivra/Desktop/project/RepresentationShaping/utils_plot.py'>

# %%
import torch
import numpy as np
from copy import deepcopy
import pickle as pkl

from torch import nn
from umap import UMAP

from run_sim import Config, run_sim, run_sim_wrapper, create_data
from utils import *
from utils_plot import *
from tqdm import tqdm
from utils import *
from functools import reduce
import os
from joblib import Parallel, delayed
import shutil

# %%
def calc_h_var(G, D, N, L, sig_X):
    return G**(2*L)*(2*D*sig_X)/(D+N)

# %%
C = Config()

C.G = 1
C.linear_net = False
C.learning_rate = 0.0001
C.data_geometry = 'MNIST'
C.L=5
C.print_progress = True
C.length_corridors = [10]*1
C.angle_range = np.pi/10
C.hidden_size = 1000 # (C.length_corridors[0]+2*C.max_move+1 + 1)*len(C.length_corridors)
C.num_epochs = 100000
C.algo_name = 'Adam'
C.loss_fn = nn.MSELoss()

C.s_range = (-1.0, 1.0)
C.poly_degree = 10
C.num_samples = 11
C.function_dim = 20
C.max_move = 0.3
C.discrete_samples = True
var_name = 'max_move'
var_values = np.linspace(0.01, 0.5, 10)
# var_name = 'L'
# var_values = np.arange(1, 10)

# %%
num_gpus = 8

# Ensure the results directory exists
results_dir = f'results/notebook_results/{var_name}'
if os.path.exists(results_dir):
    shutil.rmtree(results_dir)
os.makedirs(results_dir, exist_ok=True)

def run_and_save(var_value, index):
    C_local = deepcopy(C)
    setattr(C_local, var_name, var_value)
    C_local.gpu_id = index % num_gpus
    data_dict = run_sim_wrapper(C_local)
    out_path = os.path.join(results_dir, f'data_dict_{getattr(C_local, var_name)}.pkl')
    # Remove 'state_dict_l' and 'hidden_l' from data_dict if they exist
    data_dict.pop('state_dict_l', None)
    data_dict.pop('hidden_l', None)
    with open(out_path, 'wb') as f:
        pkl.dump(data_dict, f)
    return out_path

# Run in parallel
paths = Parallel(n_jobs=-1)(
    delayed(run_and_save)(var_value, index) for index, var_value in enumerate(var_values)
)
# Load all results into data_dict_l
data_dict_l = []
for path in paths:
    with open(path, 'rb') as f:
        data_dict_l.append(pkl.load(f))

for data_dict in data_dict_l:
    print(f'{var_name}: {getattr(data_dict["C"], var_name)} --- X shape: {data_dict["X"].shape} --- Number of hidden: {data_dict["C"].hidden_size}')
# Out:
# Number of samples: 20
# Input dimension: 21
# Output dimension: 20
# Function dimension: 20
# Action range: [-0.11888888888888888, 0.11888888888888888]
# Parameter s range: (-1.0, 1.0)
# Number of actions: 1
#
# Sig_2 of last hidden: 2.367358774790773e-06
#   0%|          | 0/100000 [00:00<?, ?it/s]24.24it/s]
# Number of samples: 10
# Input dimension: 21
# Output dimension: 20
# Function dimension: 20
# Action range: [-0.06444444444444444, 0.06444444444444444]
# Parameter s range: (-1.0, 1.0)
# Number of actions: 1
#
# Sig_2 of last hidden: 2.403646021775785e-06
#   0%|          | 2/100000 [00:00<1:23:25, 19.98it/s]]
# Number of samples: 29
# Input dimension: 21
# Output dimension: 20
# Function dimension: 20
# Action range: [-0.22777777777777777, 0.22777777777777777]
# Parameter s range: (-1.0, 1.0)
# Number of actions: 1
#
# Sig_2 of last hidden: 2.4441380901407683e-06
# Number of samples: 29
# Input dimension: 21
# Output dimension: 20
# Function dimension: 20
# Action range: [-0.2822222222222222, 0.2822222222222222]
# Parameter s range: (-1.0, 1.0)
# Number of actions: 1
#
# Sig_2 of last hidden: 2.422438910798519e-06
# Number of samples: 38
# Input dimension: 21
# Output dimension: 20
# Function dimension: 20
# Action range: [-0.33666666666666667, 0.33666666666666667]
# Parameter s range: (-1.0, 1.0)
# Number of actions: 1
#
# Sig_2 of last hidden: 2.4388784822804155e-06
# Number of samples: 10
# Input dimension: 21
# Output dimension: 20
# Function dimension: 20
# Action range: [-0.01, 0.01]
# Parameter s range: (-1.0, 1.0)
# Number of actions: 1
#
# Sig_2 of last hidden: 2.433759163977811e-06
# Number of samples: 38
# Input dimension: 21
# Output dimension: 20
# Function dimension: 20
# Action range: [-0.3911111111111111, 0.3911111111111111]
# Parameter s range: (-1.0, 1.0)
# Number of actions: 1
#
# Sig_2 of last hidden: 2.4330313408427173e-06
# Number of samples: 54
# Input dimension: 21
# Output dimension: 20
# Function dimension: 20
# Action range: [-0.5, 0.5]
# Parameter s range: (-1.0, 1.0)
# Number of actions: 1
#
# Sig_2 of last hidden: 2.7193880214326782e-06
# Number of samples: 20
# Input dimension: 21
# Output dimension: 20
# Function dimension: 20
# Action range: [-0.17333333333333334, 0.17333333333333334]
# Parameter s range: (-1.0, 1.0)
# Number of actions: 1
#
# Sig_2 of last hidden: 2.3494144443247933e-06
#   0%|          | 58/100000 [00:00<07:37, 218.27it/s]]
# Number of samples: 46
# Input dimension: 21
# Output dimension: 20
# Function dimension: 20
# Action range: [-0.44555555555555554, 0.44555555555555554]
# Parameter s range: (-1.0, 1.0)
# Number of actions: 1
#
# Sig_2 of last hidden: 2.5920526240952313e-06
# 100%|██████████| 100000/100000 [05:52<00:00, 283.36it/s]
# 100%|██████████| 100000/100000 [05:55<00:00, 281.46it/s]
# 100%|██████████| 100000/100000 [06:02<00:00, 275.75it/s]
# 100%|██████████| 100000/100000 [06:02<00:00, 275.83it/s]
# 100%|██████████| 100000/100000 [06:07<00:00, 272.08it/s]
# 100%|██████████| 100000/100000 [06:17<00:00, 265.25it/s]
# 100%|██████████| 100000/100000 [09:47<00:00, 170.25it/s]
# 100%|██████████| 100000/100000 [09:47<00:00, 170.33it/s]
# 100%|██████████| 100000/100000 [10:35<00:00, 157.35it/s]
# 100%|██████████| 100000/100000 [10:38<00:00, 156.56it/s]
# max_move: 0.01 --- X shape: torch.Size([10, 21]) --- Number of hidden: 250
# max_move: 0.06444444444444444 --- X shape: torch.Size([10, 21]) --- Number of hidden: 250
# max_move: 0.11888888888888888 --- X shape: torch.Size([20, 21]) --- Number of hidden: 250
# max_move: 0.17333333333333334 --- X shape: torch.Size([20, 21]) --- Number of hidden: 250
# max_move: 0.22777777777777777 --- X shape: torch.Size([29, 21]) --- Number of hidden: 250
# max_move: 0.2822222222222222 --- X shape: torch.Size([29, 21]) --- Number of hidden: 250
# max_move: 0.33666666666666667 --- X shape: torch.Size([38, 21]) --- Number of hidden: 250
# max_move: 0.3911111111111111 --- X shape: torch.Size([38, 21]) --- Number of hidden: 250
# max_move: 0.44555555555555554 --- X shape: torch.Size([46, 21]) --- Number of hidden: 250
# max_move: 0.5 --- X shape: torch.Size([54, 21]) --- Number of hidden: 250

# %%
def plot_pca(data_dict, title="", axs=None):
    loc_y = data_dict['loc_y']
    hidden_states = data_dict['hidden_states']
    action_taken = data_dict['action_taken']
    loss_l = data_dict['loss_l']; accuracy_l = data_dict['accuracy_l']
    y = data_dict['y'].cpu().numpy()
    C = data_dict['C']
    corridor = data_dict['corridor']
    X_np = data_dict['X'].cpu().numpy()
    final_weights = data_dict['final_weights']

    colors = loc_y

    hidden = hidden_states[-1].cpu().detach().numpy()

    PR = calc_PR(hidden)
    if not C.bias:
        W_effective = get_effective_W_from_model_dict(final_weights).cpu().numpy()
        W_PR = calc_PR(W_effective)
        if C.L == 0:
            U, S, V = np.linalg.svd(W_effective, full_matrices=False)
            hidden = X_np @ U @ np.diag(S)
    else:
        W_PR = 0
    hidden_pr = calc_PR(hidden)
    
    # alignment = alignment_score(hidden[corridor==0], hidden[corridor==1]) if n_corridors > 1 else 0
    order = get_r_2(PCA(n_components=1).fit_transform(hidden), colors)

    pca = PCA().fit(hidden)
    X_reduced = pca.transform(hidden)
    if axs is None:
        fig, axs = plt.subplots(1, 4, figsize=(25/2, 5/2))
        axs[0].set_ylabel(title)
    # Add cumulative explained variance ratio in the first row
    ax1 = axs[0]
    ax1.plot(np.cumsum(pca.explained_variance_ratio_), marker='o')
    ax1.set_xlabel('Number of Components')
    # ax1.set_ylabel('Cumulative EVR')
    ax1.set_title(f'order = {order:.2f} --- W PR = {W_PR:.2f} --- hidden PR = {hidden_pr:.2f}')
    ax1.set_ylim(-0.1, 1.1)
    
    ax1 = axs[1]
    for cor, marker in zip(np.unique(corridor), markers):
        ax1.scatter(X_reduced[corridor==cor, 0], X_reduced[corridor==cor, 1], c=colors[corridor==cor], cmap='coolwarm', alpha=0.7, marker=marker)
    ax1.set_xlabel(f'Component 1')
    ax1.set_ylabel(f'Component 2'),
    ax1.axis('equal')
    
    ax1 = axs[2]
    ax1.scatter(X_reduced[:, 0], colors, c=colors)

    axs[3].plot(loss_l)
    axs[3].set_yscale('log')
    ax2 = axs[3].twinx()
    ax2.plot(accuracy_l, 'r')
    ax2.set_ylim(-0.1, 1.1)
    axs[3].set_title("Loss")

    plt.tight_layout()

# %%
def calc_metrics(data_dict, i=-1):
    hidden = data_dict['hidden_states'][i].cpu().detach().numpy()
    PR = calc_PR(hidden)
    loc_y = data_dict['loc_y']
    order = get_r_2(PCA(n_components=1).fit_transform(hidden), loc_y)
    return PR, order

# %%
fig, axs = plt.subplots(len(data_dict_l), 4, figsize=(20/2, len(data_dict_l)*4/2))
for data_dict, axs_current in zip(data_dict_l, axs):
    plot_pca(data_dict, axs=axs_current)
    axs_current[0].set_ylabel(f'{var_name}: {getattr(data_dict["C"], var_name):.2f}')

# %%
PR_l = []
order_l = []
for data_dict in data_dict_l:
    PR, order = calc_metrics(data_dict)
    PR_l.append(PR)
    order_l.append(order)
plt.plot(var_values, PR_l, label='PR', marker='o')
plt.plot(var_values, order_l, label='order', marker='o')   
plt.legend()
plt.xlabel(var_name)
plt.ylim(0)
plt.axhline(1, color='gray', linestyle='--', alpha=0.5)
plt.show()

# %%
fig, axs = plt.subplots(1, 2, figsize=(15, 6))
for i, data_dict in enumerate(data_dict_l):
    C = data_dict['C']
    PR_l = []
    order_l = []
    for i in range(len(data_dict['hidden_states'])):
        PR, order = calc_metrics(data_dict, i)
        PR_l.append(PR)
        order_l.append(order)
    axs[0].plot(PR_l, label=f'{var_name}: {getattr(C, var_name):.2f}', marker='o')
    axs[1].plot(order_l, label=f'{var_name}: {getattr(C, var_name):.2f}', marker='o')   
axs[0].legend()
axs[0].set_xlabel('Layer')
axs[1].set_xlabel('Layer')
axs[0].set_title('PR')
axs[1].set_title('order')
axs[1].set_ylim(0)
plt.show()

# %%
X = data_dict_l[0]['X'].cpu().numpy()
loc_X = data_dict_l[0]['loc_X']
loc_y = data_dict_l[0]['loc_y']
y = data_dict_l[0]['y'].cpu().numpy()

from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)

plt.figure(figsize=(6, 5))
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=loc_y, cmap='coolwarm', alpha=0.7)
plt.xlabel('PCA Component 1')
plt.ylabel('PCA Component 2')
plt.title('PCA of X')
plt.tight_layout()
plt.show()

# %%
from data_modules import create_data_non_linear_fn
from model import DNN
C = data_dict_l[0]['C']
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
for data_dict in [data_dict_l[0], data_dict_l[-1]]:
    loc_X = data_dict['loc_X']
    outputs = data_dict['outputs']
    X = data_dict['X'].cpu().numpy()
    C.num_samples = 1000
    X, y, corridor, loc_X, loc_y, action_taken, dim_l, input_size, output_size, n_actions = create_data(C)
    X = torch.tensor(X, dtype=torch.float32).to(device)
    y = torch.tensor(y, dtype=torch.float32).to(device)
    model = DNN(input_size + n_actions, C.hidden_size, output_size, C.L, C.fixed_output, C.linear_net, C.G, C.bias).to(device)
    model.load_state_dict(data_dict['final_weights'])
    outputs = model(X)[0].detach().cpu().numpy()
    X = X.cpu().numpy()
    i = 2
    plt.plot(loc_X[:,0], X[:,i],)
    plt.plot(loc_X[:,0], outputs[:,i])
    plt.legend()
    plt.show()
# Out:
# Number of samples: 10964
# Input dimension: 21
# Output dimension: 20
# Function dimension: 20
# Action range: [-0.01, 0.01]
# Parameter s range: (-1.0, 1.0)
# Number of actions: 1
# /tmp/ipykernel_1934997/3882829254.py:20: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# Number of samples: 10964
# Input dimension: 21
# Output dimension: 20
# Function dimension: 20
# Action range: [-0.01, 0.01]
# Parameter s range: (-1.0, 1.0)
# Number of actions: 1
